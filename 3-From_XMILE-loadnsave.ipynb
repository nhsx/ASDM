# %%
#!pip install netCDF4 matplotlib pandas tqdm networkx

# %%
#!pip install lxml-4.9.0-cp311-cp311-win_amd64.whl

# %%
from ASDM.Engine import Structure
import pandas as pd
pd.options.display.max_columns = 100

# %%
modelnow = "Delays"

# %%
model = Structure(from_xmile='BuiltInTestModels/'+modelnow+'.stmx ')

# model = Structure(from_xmile='BuiltInTestModels/Goal_gap.stmx')
# model = Structure(from_xmile='BuiltInTestModels/Goal_gap_array.stmx')
# model = Structure(from_xmile='BuiltInTestModels/Built_in_vars.stmx')
# model = Structure(from_xmile='BuiltInTestModels/IF_THEN_ELSE.stmx')
# model = Structure(from_xmile='BuiltInTestModels/Graph_function.stmx ')
# model = Structure(from_xmile='BuiltInTestModels/Array_cross_reference.stmx ')
#model = Structure(from_xmile='BuiltInTestModels/Delays.stmx ')
# model = Structure(from_xmile='BuiltInTestModels/Logic.stmx ')
#model = Structure(from_xmile='BuiltInTestModels/Conveyor.stmx ')
#model = Structure(from_xmile='BuiltInTestModels/Conveyor_leakage.stmx ')
#model = Structure(from_xmile='Other files/population-1.stmx')

# %%
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()

# %%
df_outcome.plot()
# Out:
# <AxesSubplot: xlabel='Months'>

# %%
# new_columns = [n.replace('_', ' ') for n in list(df_outcome.columns)]
# column_name_map = dict(zip(df_outcome.columns, new_columns))

# df_outcome.rename(columns=column_name_map, inplace=True)
# df_outcome.drop(['TIME'], axis=1, inplace=True)

# %%
df_outcome[sorted(df_outcome.columns)];

# %%
df_outcome
# Out:
#         Flow 1  Flow 2  Flow 3
# Months
# 1.0        1.0     4.0     1.0
# 1.5        1.5     4.0     1.0
# 2.0        2.0     4.0     1.0
# 2.5        2.5     4.0     1.0
# 3.0        3.0     1.0     1.0
# 3.5        3.5     1.5     1.5
# 4.0        4.0     2.0     2.0
# 4.5        4.5     2.5     2.5
# 5.0        5.0     3.0     3.0
# 5.5        5.5     3.5     3.5
# 6.0        6.0     4.0     4.0
# 6.5        6.5     4.5     4.5
# 7.0        7.0     5.0     5.0

# %%
df_outcome.to_csv("./BuiltInTestModels/Outputs/"+modelnow+".csv")

# %% [markdown]
# ## Goal gap

# %%
modelnow = "Goal_gap"
model = Structure(from_xmile='BuiltInTestModels/'+modelnow+'.stmx ')
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()
df_outcome.plot()
df_outcome.to_csv("./BuiltInTestModels/Outputs/"+modelnow+".csv")

# %% [markdown]
# ## Goal-gap array

# %%
modelnow = "Goal_gap_array"
model = Structure(from_xmile='BuiltInTestModels/'+modelnow+'.stmx ')
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()
df_outcome.plot()
df_outcome.to_csv("./BuiltInTestModels/Outputs/"+modelnow+".csv")
# Out:
# {'Dim1': ['1', '2'], 'Dim2': ['First', 'Second']}

# %% [markdown]
# ## Conveyor

# %%
modelnow = "Conveyor"
model = Structure(from_xmile='BuiltInTestModels/'+modelnow+'.stmx ')
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()
df_outcome.plot()
df_outcome.to_csv("./BuiltInTestModels/Outputs/"+modelnow+".csv")

# %% [markdown]
# ## Conveyor-time

# %%
modelnow = "Conveyor_time"
model = Structure(from_xmile='BuiltInTestModels/'+modelnow+'.stmx ')
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()
df_outcome.plot()
df_outcome.to_csv("./BuiltInTestModels/Outputs/"+modelnow+".csv")

# %% [markdown]
# ## Leaked conveyor

# %%
modelnow = "Conveyor_leakage"
model = Structure(from_xmile='BuiltInTestModels/'+modelnow+'.stmx ')
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()
df_outcome.plot()
df_outcome.to_csv("./BuiltInTestModels/Outputs/"+modelnow+".csv")

# %% [markdown]
# ## IF_THEN_ELSE

# %%
modelnow = "IF_THEN_ELSE"
model = Structure(from_xmile='BuiltInTestModels/'+modelnow+'.stmx ')
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()
df_outcome.plot()
df_outcome.to_csv("./BuiltInTestModels/Outputs/"+modelnow+".csv")

# %% [markdown]
# ## Logic

# %%
modelnow = "Logic"
model = Structure(from_xmile='BuiltInTestModels/'+modelnow+'.stmx ')
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()
#df_outcome.plot()
df_outcome.to_csv("./BuiltInTestModels/Outputs/"+modelnow+".csv")

# %% [markdown]
# ## Built in vars

# %%
modelnow = "Built_in_vars"
model = Structure(from_xmile='BuiltInTestModels/'+modelnow+'.stmx ')
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()
df_outcome.plot()
df_outcome.to_csv("./BuiltInTestModels/Outputs/"+modelnow+".csv")

# %% [markdown]
# ## Array_cross_reference

# %%
modelnow = "Array_cross_reference"
model = Structure(from_xmile='BuiltInTestModels/'+modelnow+'.stmx ')
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()
df_outcome.plot()
df_outcome.to_csv("./BuiltInTestModels/Outputs/"+modelnow+".csv")
# Out:
# {'Dimension_1': ['1', '2'], 'Dimension_2': ['Element_1', 'Element_2']}

# %% [markdown]
# ## Modules

# %%
modelnow = "Modules"
model = Structure(from_xmile='BuiltInTestModels/'+modelnow+'.stmx ')
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()
df_outcome.plot()
df_outcome.to_csv("./BuiltInTestModels/Outputs/"+modelnow+".csv")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[47], line 2
#       1 modelnow = "Modules"
# ----> 2 model = Structure(from_xmile='BuiltInTestModels/'+modelnow+'.stmx ')
#       3 model.clear_last_run()
#       4 model.simulate()
#
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:433, in Structure.__init__(self, subscripts, from_xmile)
#     430 # create auxiliaries
#     431 for auxiliary in auxiliaries:
#     432     # self.add_aux(self.name_handler(auxiliary.get('name')), equation=auxiliary.find('eqn').text)
# --> 433     self.add_aux(self.name_handler(auxiliary.get('name')), equation=subscripted_equation(auxiliary))
#     435 # create flows
#     436 for flow in flows:
#
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:407, in Structure.__init__.<locals>.subscripted_equation(var)
# ...

# %% [markdown]
# ## Graph function

# %%
modelnow = "Graph_function"
model = Structure(from_xmile='BuiltInTestModels/'+modelnow+'.stmx ')
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()
df_outcome.plot()
df_outcome.to_csv("./BuiltInTestModels/Outputs/"+modelnow+".csv")
