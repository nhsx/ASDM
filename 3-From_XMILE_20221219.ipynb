# %%
from ASDM.Engine import Structure
import pandas as pd
pd.options.display.max_columns = 100

# %%
# !pip install tqdm
# Out:
# Collecting tqdm
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: colorama in c:\users\martina.f (14dd7890)\onedrive - nhs england\documents\projects\asdm\asdm\lib\site-packages (from tqdm) (0.4.6)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.64.1

# %% [markdown]
# ## ASDM from XMILE

# %%
# model = Structure(from_xmile='BuiltInTestModels/Goal_gap.stmx')
# model = Structure(from_xmile='BuiltInTestModels/Goal_gap_array.stmx')
# model = Structure(from_xmile='BuiltInTestModels/Built_in_vars.stmx')
# model = Structure(from_xmile='BuiltInTestModels/IF_THEN_ELSE.stmx')
# model = Structure(from_xmile='BuiltInTestModels/Graph_function.stmx ')
# model = Structure(from_xmile='BuiltInTestModels/Array_cross_reference.stmx ')
# model = Structure(from_xmile='BuiltInTestModels/Delays.stmx ')
# model = Structure(from_xmile='BuiltInTestModels/Logic.stmx ')
# model = Structure(from_xmile='BuiltInTestModels/Conveyor.stmx ')
# model = Structure(from_xmile='BuiltInTestModels/Conveyor_leakage.stmx ')
model = Structure(from_xmile='Other files/population-1.stmx ')

# %%
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()

# %%
df_outcome.plot()
# Out:
# <AxesSubplot: xlabel='year'>

# %%
df_outcome.head()
# Out:
#       population  birth rate  average lifespan     births    deaths
# year
# 1.0   100.000000         0.1              80.0  10.000000  1.250000
# 1.5   104.375000         0.1              80.0  10.437500  1.304688
# 2.0   108.941406         0.1              80.0  10.894141  1.361768
# 2.5   113.707593         0.1              80.0  11.370759  1.421345
# 3.0   118.682300         0.1              80.0  11.868230  1.483529

# %% [markdown]
# ## ASDM from XMILE - population py>simlin>stmx

# %%
model = Structure(from_xmile='Other files/my1010-93.stmx')

# %%
model.clear_last_run()
model.simulate()
df_outcome = model.export_simulation_result()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# ...
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1268, in Structure.calculate_experiment(self, expression, subscript)
#    1266 try:
#    1267     # print(self.n_indentation*'\t' + 'eval:', equation)
# -> 1268     value = eval(str(equation), self.custom_functions)
#    1269     # print(self.n_indentation*'\t'+'Evaluated {} = {}'.format(equation, value))
#
# File <string>:1
#
# NameError: name 'Susceptible_i' is not defined
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 model.clear_last_run()
# ----> 2 model.simulate()
#       3 df_outcome = model.export_simulation_result()
#
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:805, in Structure.simulate(self, simulation_time, dt, progress_bar)
#     803 if self.is_initialised == False:
#     804     self.__built_in_variables['TIME'].append(self.initial_time) # initialization of stocks might require TIME
# --> 805     self.init_stocks()
#     806 else:
#     807     self.update_stocks(self.dt)
#
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:842, in Structure.init_stocks(self)
#     839     conveyor = equation
#     840     equation = equation.equation
# --> 842 value = self.calculate_experiment(equation, ix)
#     844 self.__name_values[self.current_time][element][ix] = value
#     846 if is_conveyor:
#
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1275, in Structure.calculate_experiment(self, expression, subscript)
#    1273 p = s.split("'")[1]
#    1274 # print(self.n_indentation*'\t'+'NameError {} for equation: {}'.format(p,equation))
# -> 1275 val = self.calculate_experiment(p, subscript)
#    1276 # print(self.n_indentation*'\t'+'Calculated value for {}: {}'.format(p, val))
#    1277 val_str = str(val)
#
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1275, in Structure.calculate_experiment(self, expression, subscript)
#    1273 p = s.split("'")[1]
#    1274 # print(self.n_indentation*'\t'+'NameError {} for equation: {}'.format(p,equation))
# -> 1275 val = self.calculate_experiment(p, subscript)
#    1276 # print(self.n_indentation*'\t'+'Calculated value for {}: {}'.format(p, val))
#    1277 val_str = str(val)
#
#     [... skipping similar frames: Structure.calculate_experiment at line 1275 (2965 times)]
#
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1275, in Structure.calculate_experiment(self, expression, subscript)
#    1273 p = s.split("'")[1]
#    1274 # print(self.n_indentation*'\t'+'NameError {} for equation: {}'.format(p,equation))
# -> 1275 val = self.calculate_experiment(p, subscript)
#    1276 # print(self.n_indentation*'\t'+'Calculated value for {}: {}'.format(p, val))
#    1277 val_str = str(val)
#
# File ~\OneDrive - NHS England\Documents\Projects\ASDM\ASDM\Engine.py:1155, in Structure.calculate_experiment(self, expression, subscript)
#    1153 if type(equation) is str:
#    1154     reg = "(?<!(<|>|=))=(?!(<|>|=))"
# -> 1155     equation = re.sub(reg, "==", equation)
#    1157 value = None
#    1159 while type(value) not in [int, float, np.int64, bool]: # if value has not become a number (taking care of the numpy data types)
#    1160
#    1161     # check if the variable is a graph function which has an additonal layer that transforms the equation outcome
#
# File C:\Python311\Lib\re\__init__.py:185, in sub(pattern, repl, string, count, flags)
#     178 def sub(pattern, repl, string, count=0, flags=0):
#     179     """Return the string obtained by replacing the leftmost
#     180     non-overlapping occurrences of the pattern in string by the
#     181     replacement repl.  repl can be either a string or a callable;
#     182     if a string, backslash escapes in it are processed.  If it is
#     183     a callable, it's passed the Match object and must return
#     184     a replacement string to be used."""
# --> 185     return _compile(pattern, flags).sub(repl, string, count)
#
# File C:\Python311\Lib\re\__init__.py:274, in _compile(pattern, flags)
#     272 def _compile(pattern, flags):
#     273     # internal: compile pattern
# --> 274     if isinstance(flags, RegexFlag):
#     275         flags = flags.value
#     276     try:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
df_outcome.plot()

# %%
df_outcome.head()
